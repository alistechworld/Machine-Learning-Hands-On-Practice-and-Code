# %% [markdown]
# <a href="https://colab.research.google.com/github/alistechworld/Machine-Learning-Hands-On-Practice-and-Code/blob/main/Day_19_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Working with dates and times

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb7c9b21-0be9-4f6d-ab62-ebdcfce39fc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb7c9b21-0be9-4f6d-ab62-ebdcfce39fc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head(2)
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157

# %%
time.head(2)
# Out:
#                   date                                               msg
# 0  2013-12-15 00:50:00                          ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00  ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
# Working With Dates
# Converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
# 1. Extract Year

date['date_year'] = date['date'].dt.year
date.sample(2)
# Out:
#           date  product_id  city_id  orders  date_year
# 542 2019-06-10        2652       18      69       2019
# 72  2018-08-27        7582       17      30       2018

# %%
# 2. Extract Month
date['date_month_no'] = date['date'].dt.month
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1

# %%
date['date_month_name'] = date['date'].dt.month_name()
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name
# 0        December
# 1          August
# 2         October
# 3          August
# 4         January

# %%
# Extract Days
date['date_day'] = date['date'].dt.day

date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_day
# 0        December        10
# 1          August        15
# 2         October        23
# 3          August        17
# 4         January         6

# %%
# Day of Week - name
date['date_dow_name'] = date['date'].dt.day_name()

date.drop(columns=['product_id', 'city_id', 'orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day date_dow_name
# 0 2019-12-10       2019             12        December        10       Tuesday
# 1 2018-08-15       2018              8          August        15     Wednesday
# 2 2018-10-23       2018             10         October        23       Tuesday
# 3 2019-08-17       2019              8          August        17      Saturday
# 4 2019-01-06       2019              1         January         6        Sunday

# %%
# is weekend?

date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday', 'Saturday']), 1,0)
date.drop(columns=['product_id', 'city_id', 'orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#   date_dow_name  date_is_weekend
# 0       Tuesday                0
# 1     Wednesday                0
# 2       Tuesday                0
# 3      Saturday                1
# 4        Sunday                1

# %%
date['date_week'] = date['date'].dt.isocalendar().week

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#   date_dow_name  date_is_weekend  date_week
# 0       Tuesday                0         50
# 1     Wednesday                0         33
# 2       Tuesday                0         43
# 3      Saturday                1         33
# 4        Sunday                1          1

# %%
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#   date_dow_name  date_is_weekend  date_week  quarter
# 0       Tuesday                0         50        4
# 1     Wednesday                0         33        3
# 2       Tuesday                0         43        4
# 3      Saturday                1         33        3
# 4        Sunday                1          1        1

# %%
# Extract Semester
date['semester'] = np.where(date['quarter'].isin([1,2]), 1,2)

date.drop(columns=['product_id', 'city_id', 'orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6
#
#   date_dow_name  date_is_weekend  date_week  quarter  semester
# 0       Tuesday                0         50        4         2
# 1     Wednesday                0         33        3         2
# 2       Tuesday                0         43        4         2
# 3      Saturday                1         33        3         2
# 4        Sunday                1          1        1         1

# %%
# Extract Time Elapsed between dates

# %%
import datetime
today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2025, 8, 14, 4, 3, 59, 325865)

# %%
today - date['date']
# Out:
# 0     2074 days 04:03:59.325865
# 1     2556 days 04:03:59.325865
# 2     2487 days 04:03:59.325865
# 3     2189 days 04:03:59.325865
# 4     2412 days 04:03:59.325865
#                  ...
# 995   2502 days 04:03:59.325865
# 996   2443 days 04:03:59.325865
# 997   2291 days 04:03:59.325865
# 998   2356 days 04:03:59.325865
# 999   2130 days 04:03:59.325865
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      2074
# 1      2556
# 2      2487
# 3      2189
# 4      2412
#        ...
# 995    2502
# 996    2443
# 997    2291
# 998    2356
# 999    2130
# Name: date, Length: 1000, dtype: int64

# %%
# Month Passed
# np.round((today - date['date']) / np.timedelta64(1, 'M'), 0)

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
# Converting to datetime datatype
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %%
# Extract Time Part
time['time'] = time['date'].dt.time

time.head(2)
# Out:
#                  date                                               msg  hour  \
# 0 2013-12-15 00:50:00                          ищу на сегодня мужика 37     0
# 1 2014-04-29 23:40:00  ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826    23
#
#    min  sec      time
# 0   50    0  00:50:00
# 1   40    0  23:40:00

# %%
# Time Difference
today - time['date']
# Out:
# 0     4260 days 03:13:59.325865
# 1     4124 days 04:23:59.325865
# 2     4610 days 03:42:59.325865
# 3     3912 days 03:32:59.325865
# 4     4309 days 04:52:59.325865
#                  ...
# 995   4899 days 03:13:59.325865
# 996   4220 days 04:49:59.325865
# 997   4685 days 04:26:59.325865
# 998   4801 days 04:29:59.325865
# 999   4073 days 04:38:59.325865
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# In seconds
(today - time['date'])/np.timedelta64(1, 's')
# Out:
# 0      3.680756e+08
# 1      3.563294e+08
# 2      3.983174e+08
# 3      3.380096e+08
# 4      3.723152e+08
#            ...
# 995    4.232852e+08
# 996    3.646254e+08
# 997    4.048000e+08
# 998    4.148226e+08
# 999    3.519239e+08
# Name: date, Length: 1000, dtype: float64

# %%
# In Minutes
# (today - time['date']/np.timedelta64(1, 'm'))

# %%
# In Hours
(today - time['date'])/np.timedelta64(1, 'h')
# Out:
# 0      102243.233146
# 1       98980.399813
# 2      110643.716479
# 3       93891.549813
# 4      103420.883146
#            ...
# 995    117579.233146
# 996    101284.833146
# 997    112444.449813
# 998    115228.499813
# 999     97756.649813
# Name: date, Length: 1000, dtype: float64
